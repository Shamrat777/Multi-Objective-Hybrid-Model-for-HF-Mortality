# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-b18609cf-4349-4490-901b-a5d59beb895d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b18609cf-4349-4490-901b-a5d59beb895d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
x=df.drop(['DEATH_EVENT'], axis = 'columns')
y=df['DEATH_EVENT']

# %%
#!pip install -U imbalanced-learn
from imblearn.combine import SMOTETomek
sm = SMOTETomek()
x_sm, y_sm = sm.fit_resample(x, y)

# %%
from sklearn.inspection import PartialDependenceDisplay

# %%
from sklearn.ensemble import RandomForestClassifier
my_model = RandomForestClassifier().fit(x_sm, y_sm)

# %%
from sklearn.ensemble import RandomForestClassifier
my_model1 = RandomForestClassifier().fit(x, y)

# %%
x_sm.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time'],
#       dtype='object')

# %%
smoking = PartialDependenceDisplay.from_estimator(my_model1,x,features = ['smoking'])
fig, ax = plt.subplots(figsize=(4,2.5))
smoking.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('smoking.pdf', bbox_inches='tight')
plt.show()

# %%
serum_sodium = PartialDependenceDisplay.from_estimator(my_model,x_sm,features = ['serum_sodium'])
fig, ax = plt.subplots(figsize=(4,2.5))
serum_sodium.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('serum_sodium.pdf', bbox_inches='tight')
plt.show()

# %%
platelets = PartialDependenceDisplay.from_estimator(my_model,x_sm,features = ['platelets'])
fig, ax = plt.subplots(figsize=(3.5,2.5))
platelets.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('platelets.pdf', bbox_inches='tight')
plt.show()

# %%
diabetes = PartialDependenceDisplay.from_estimator(my_model1,x,features = ['diabetes'])
fig, ax = plt.subplots(figsize=(4,2.5))
diabetes.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('diabetes.pdf', bbox_inches='tight')
plt.show()

# %%
time = PartialDependenceDisplay.from_estimator(my_model,x_sm,features = ['time'])
fig, ax = plt.subplots(figsize=(4,2.5))
time.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('time.pdf', bbox_inches='tight')
plt.show()

# %%
ejection_fraction = PartialDependenceDisplay.from_estimator(my_model,x_sm,features = ['ejection_fraction'])
fig, ax = plt.subplots(figsize=(4,2.5))
ejection_fraction.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('ejection_fraction.pdf', bbox_inches='tight')
plt.show()

# %%
serum_creatinine = PartialDependenceDisplay.from_estimator(my_model,x_sm,features = ['serum_creatinine'])
fig, ax = plt.subplots(figsize=(4,2.5))
serum_creatinine.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('serum_creatinine.pdf', bbox_inches='tight')
plt.show()

# %%
creatinine_phosphokinase = PartialDependenceDisplay.from_estimator(my_model,x_sm,features = ['creatinine_phosphokinase'])
fig, ax = plt.subplots(figsize=(4,2.5))
creatinine_phosphokinase.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('creatinine_phosphokinase.pdf', bbox_inches='tight')
plt.show()

# %%
anaemia = PartialDependenceDisplay.from_estimator(my_model,x_sm,features = ['anaemia'])
fig, ax = plt.subplots(figsize=(4,2.5))
anaemia.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('anaemia.pdf', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.inspection import PartialDependenceDisplay

age = PartialDependenceDisplay.from_estimator(my_model,x_sm,features = ['age'])
fig, ax = plt.subplots(figsize=(4,2.5))
age.plot(line_kw={"color": 'black'}, ax=ax)
plt.rcParams['lines.linewidth'] = 2
plt.savefig('age.pdf', bbox_inches='tight')
plt.show()

# %%
import numpy as np
df = df.replace({"?":np.NAN})
df
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     41   F            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 3767  30   F            f                  f                         f    f
# 3768  68   F            f                  f                         f    f
# 3769  74   F            f                  f                         f    f
# 3770  72   M            f                  f                         f    f
# 3771  64   F            f                  f                         f    f
#
# ...

# %%
df=df.drop(["TBG"],axis='columns')

from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = label_encoder.fit_transform(df[column])

cols = df.columns[df.dtypes.eq('object')]
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df= df.interpolate(method = 'median', order = 4)
df.isna().sum()
# Out:
# age                          0
# sex                          0
# on_thyroxine                 0
# query_on_thyroxine           0
# on_antithyroid_medication    0
# sick                         0
# pregnant                     0
# thyroid_surgery              0
# I131_treatment               0
# query_hypothyroid            0
# query_hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH_measured                 0
# TSH                          0
# T3_measured                  0
# T3                           0
# TT4_measured                 0
# TT4                          0
# T4U_measured                 0
# T4U                          0
# FTI_measured                 0
# FTI                          0
# TBG_measured                 0
# referral_source              0
# Class                        0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,28]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.20)

# %%
from sklearn.ensemble import AdaBoostClassifier
from imblearn.combine import SMOTETomek

# %%
def adaboost(x, y):
    model = AdaBoostClassifier()
    model.fit(x,y)
    y_pred = model.predict(x)
    return y_pred

sm = SMOTETomek()
x_sm, y_sm = sm.fit_resample(x, y)
y_smote = adaboost(x_sm, y_sm)

# %%
T3 0.5406
Age 0.4562
TT4 0.4285
FTI 0.4218
TSH 0.3418
Sex 0.1779
T3 Measured 0.0542
TT4 Measured 0.0375
On Thyroxine 0.0373
Psych 0.0202
TSH Measured 0.0157
Pregnant 0.0148
Tumor 0.0142
Hypopituitary 0.0125

# %%
selected_features = ['age', 'sex', 'on_thyroxine', 'psych',
                     'T3_measured', 'T3', 'TT4_measured', 'TT4',
                     'FTI', 'TSH', 'pregnant', 'tumor']

UVSf = x_sm[selected_features].copy()

# %%
pip install SHAP
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 9.9 MB/s eta 0:00:00
# ...

# %%
X_trainu, X_testu, y_trainu, y_testu = train_test_split(UVSf, y_sm, test_size=0.2)

# %%
import shap

explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(UVSf)

shap.summary_plot(shap_values, UVSf)

# %%
import matplotlib.pyplot as plt

# Assuming 'shap_values' and 'X' are already computed
shap.summary_plot(shap_values, UVSf, show=False)  # Set show=False to prevent displaying the plot

# Adjust the size of the plot
plt.gcf().set_size_inches(6, 4)  # Adjust the width and height as needed

# Save the plot as a PDF file
plt.savefig('shap_summary_plot.pdf', bbox_inches='tight')

# Optionally, show the plot
plt.show()
